# %% [markdown]
# <a href="https://colab.research.google.com/github/Jaseem1911/DataPreprocessing/blob/main/IrisSeaborn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/drive/MyDrive/IRIS.csv')
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
sns.jointplot(x='sepal_length',y='sepal_width' ,data=df ,kind='reg')

# %%
sns.kdeplot(df['sepal_length'])

# %%
sns.pairplot(df)

# %%
sns.rugplot(df['sepal_width'])

# %%
sns.barplot(x='petal_length', y='petal_width', data=df, estimator=np.median)

# %%
sns.countplot(x='sepal_width', data=df)

# %%
sns.boxplot(x='sepal_length', y='sepal_width',data=df)

# %%
sns.violinplot(x='sepal_length', y='sepal_width',data=df)

# %%
sns.stripplot(x='sepal_length', y='sepal_width',data=df, jitter=True, dodge=True)

# %%
sns.violinplot(x='sepal_length', y='sepal_width',data=df)
sns.swarmplot(x='sepal_length', y='sepal_width',data=df, color='white')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 50.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 40.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 33.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 20.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
sns.relplot(x="petal_length",y="petal_width",data=df)

# %%
sns.relplot(x="petal_length",y="petal_width",data=df,kind='line')

# %%
sns.catplot(x="petal_length",y="petal_width",data=df)

# %%
sns.catplot(x="petal_length",y="petal_width",data=df,kind='violin')

# %%
sns.catplot(x="petal_length",y="petal_width",data=df,kind='boxen')

# %%
sns.displot(df)

# %%
sns.set(style="white",color_codes=True)
df=sns.load_dataset("iris")
sns.boxplot(x="sepal_length", y="sepal_width",data=df)

# %%
sns.set(style="white",color_codes=True)
df=sns.load_dataset("iris")
sns.boxplot(x="sepal_length", y="sepal_width",data=df)
sns.despine(offset=10,trim=True)
