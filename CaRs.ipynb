# %% [markdown]
# <a href="https://colab.research.google.com/github/Jaseem1911/DataPreprocessing/blob/main/CaRs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('/content/drive/MyDrive/cars.csv',sep=';')
data
# Out:
#                            Car     MPG Cylinders Displacement Horsepower  \
# 0                       STRING  DOUBLE       INT       DOUBLE     DOUBLE
# 1    Chevrolet Chevelle Malibu    18.0         8        307.0      130.0
# 2            Buick Skylark 320    15.0         8        350.0      165.0
# 3           Plymouth Satellite    18.0         8        318.0      150.0
# 4                AMC Rebel SST    16.0         8        304.0      150.0
# ..                         ...     ...       ...          ...        ...
# 402            Ford Mustang GL    27.0         4        140.0      86.00
# 403          Volkswagen Pickup    44.0         4        97.00      52.00
# 404              Dodge Rampage    32.0         4        135.0      84.00
# 405                Ford Ranger    28.0         4        120.0      79.00
# 406                 Chevy S-10    31.0         4        119.0      82.00
#
#      Weight Acceleration Model  Origin
# 0    DOUBLE       DOUBLE   INT     CAT
# ...

# %%
data.shape
# Out:
# (407, 9)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 407 entries, 0 to 406
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Car           407 non-null    object
#  1   MPG           407 non-null    object
#  2   Cylinders     407 non-null    object
#  3   Displacement  407 non-null    object
#  4   Horsepower    407 non-null    object
#  5   Weight        407 non-null    object
#  6   Acceleration  407 non-null    object
#  7   Model         407 non-null    object
#  8   Origin        407 non-null    object
# dtypes: object(9)
# memory usage: 28.7+ KB

# %%
data.isna().sum()
# Out:
# Car             0
# MPG             0
# Cylinders       0
# Displacement    0
# Horsepower      0
# Weight          0
# Acceleration    0
# Model           0
# Origin          0
# dtype: int64

# %%
data.dtypes
# Out:
# Car             object
# MPG             object
# Cylinders       object
# Displacement    object
# Horsepower      object
# Weight          object
# Acceleration    object
# Model           object
# Origin          object
# dtype: object

# %%
data.head(10)
# Out:
#                          Car     MPG Cylinders Displacement Horsepower  \
# 0                     STRING  DOUBLE       INT       DOUBLE     DOUBLE
# 1  Chevrolet Chevelle Malibu    18.0         8        307.0      130.0
# 2          Buick Skylark 320    15.0         8        350.0      165.0
# 3         Plymouth Satellite    18.0         8        318.0      150.0
# 4              AMC Rebel SST    16.0         8        304.0      150.0
# 5                Ford Torino    17.0         8        302.0      140.0
# 6           Ford Galaxie 500    15.0         8        429.0      198.0
# 7           Chevrolet Impala    14.0         8        454.0      220.0
# 8          Plymouth Fury iii    14.0         8        440.0      215.0
# 9           Pontiac Catalina    14.0         8        455.0      225.0
#
#    Weight Acceleration Model Origin
# 0  DOUBLE       DOUBLE   INT    CAT
# 1   3504.         12.0    70     US
# 2   3693.         11.5    70     US
# 3   3436.         11.0    70     US
# ...

# %%
data.drop(index=0)
# Out:
#                            Car   MPG Cylinders Displacement Horsepower Weight  \
# 1    Chevrolet Chevelle Malibu  18.0         8        307.0      130.0  3504.
# 2            Buick Skylark 320  15.0         8        350.0      165.0  3693.
# 3           Plymouth Satellite  18.0         8        318.0      150.0  3436.
# 4                AMC Rebel SST  16.0         8        304.0      150.0  3433.
# 5                  Ford Torino  17.0         8        302.0      140.0  3449.
# ..                         ...   ...       ...          ...        ...    ...
# 402            Ford Mustang GL  27.0         4        140.0      86.00  2790.
# 403          Volkswagen Pickup  44.0         4        97.00      52.00  2130.
# 404              Dodge Rampage  32.0         4        135.0      84.00  2295.
# 405                Ford Ranger  28.0         4        120.0      79.00  2625.
# 406                 Chevy S-10  31.0         4        119.0      82.00  2720.
#
#     Acceleration Model  Origin
# ...

# %%
data.drop('Car',axis=1,inplace=True)
data
# Out:
#         MPG Cylinders Displacement Horsepower  Weight Acceleration Model  \
# 0    DOUBLE       INT       DOUBLE     DOUBLE  DOUBLE       DOUBLE   INT
# 1      18.0         8        307.0      130.0   3504.         12.0    70
# 2      15.0         8        350.0      165.0   3693.         11.5    70
# 3      18.0         8        318.0      150.0   3436.         11.0    70
# 4      16.0         8        304.0      150.0   3433.         12.0    70
# ..      ...       ...          ...        ...     ...          ...   ...
# 402    27.0         4        140.0      86.00   2790.         15.6    82
# 403    44.0         4        97.00      52.00   2130.         24.6    82
# 404    32.0         4        135.0      84.00   2295.         11.6    82
# 405    28.0         4        120.0      79.00   2625.         18.6    82
# 406    31.0         4        119.0      82.00   2720.         19.4    82
#
#      Origin
# 0       CAT
# 1        US
# 2        US
# 3        US
# 4        US
# ...

# %%
data.drop('Origin',axis=1,inplace=True)
data
# Out:
#         MPG Cylinders Displacement Horsepower  Weight Acceleration Model
# 0    DOUBLE       INT       DOUBLE     DOUBLE  DOUBLE       DOUBLE   INT
# 1      18.0         8        307.0      130.0   3504.         12.0    70
# 2      15.0         8        350.0      165.0   3693.         11.5    70
# 3      18.0         8        318.0      150.0   3436.         11.0    70
# 4      16.0         8        304.0      150.0   3433.         12.0    70
# ..      ...       ...          ...        ...     ...          ...   ...
# 402    27.0         4        140.0      86.00   2790.         15.6    82
# 403    44.0         4        97.00      52.00   2130.         24.6    82
# 404    32.0         4        135.0      84.00   2295.         11.6    82
# 405    28.0         4        120.0      79.00   2625.         18.6    82
# 406    31.0         4        119.0      82.00   2720.         19.4    82
#
# [407 rows x 7 columns]

# %%
dataa=data.drop(index=0)
dataa
# Out:
#       MPG Cylinders Displacement Horsepower Weight Acceleration Model
# 1    18.0         8        307.0      130.0  3504.         12.0    70
# 2    15.0         8        350.0      165.0  3693.         11.5    70
# 3    18.0         8        318.0      150.0  3436.         11.0    70
# 4    16.0         8        304.0      150.0  3433.         12.0    70
# 5    17.0         8        302.0      140.0  3449.         10.5    70
# ..    ...       ...          ...        ...    ...          ...   ...
# 402  27.0         4        140.0      86.00  2790.         15.6    82
# 403  44.0         4        97.00      52.00  2130.         24.6    82
# 404  32.0         4        135.0      84.00  2295.         11.6    82
# 405  28.0         4        120.0      79.00  2625.         18.6    82
# 406  31.0         4        119.0      82.00  2720.         19.4    82
#
# [406 rows x 7 columns]

# %%
dataa.head(40)
# Out:
#      MPG Cylinders Displacement Horsepower Weight Acceleration Model
# 1   18.0         8        307.0      130.0  3504.         12.0    70
# 2   15.0         8        350.0      165.0  3693.         11.5    70
# 3   18.0         8        318.0      150.0  3436.         11.0    70
# 4   16.0         8        304.0      150.0  3433.         12.0    70
# 5   17.0         8        302.0      140.0  3449.         10.5    70
# 6   15.0         8        429.0      198.0  4341.         10.0    70
# 7   14.0         8        454.0      220.0  4354.          9.0    70
# 8   14.0         8        440.0      215.0  4312.          8.5    70
# 9   14.0         8        455.0      225.0  4425.         10.0    70
# 10  15.0         8        390.0      190.0  3850.          8.5    70
# 11     0         4        133.0      115.0  3090.         17.5    70
# 12     0         8        350.0      165.0  4142.         11.5    70
# 13     0         8        351.0      153.0  4034.         11.0    70
# ...

# %%
dataa.columns
# Out:
# Index(['MPG', 'Cylinders', 'Displacement', 'Horsepower', 'Weight',
#        'Acceleration', 'Model'],
#       dtype='object')

# %%
dataa.isna().sum()
# Out:
# MPG             0
# Cylinders       0
# Displacement    0
# Horsepower      0
# Weight          0
# Acceleration    0
# Model           0
# dtype: int64

# %%
# split the dataset and create the model
dataa.columns
y=dataa['Model']
x=dataa.drop('Model',axis=1)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=42,test_size=0.2)

# %%
# create linear model
from sklearn import linear_model
lr=linear_model.LinearRegression()
model=lr.fit(x_train,y_train)
prediction=model.predict(x_test)

# %%
# check the mse
from sklearn.metrics import mean_squared_error
print('MSE is:',mean_squared_error(y_test,prediction))
# Out:
# MSE is: 7.729717378652255

# %%
# r^2 ed value
from sklearn.metrics import r2_score
print('R squared value is',r2_score(y_test,prediction))
# Out:
# R squared value is 0.4954312320008373
